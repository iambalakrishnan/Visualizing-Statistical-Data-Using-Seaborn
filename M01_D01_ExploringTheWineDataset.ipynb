# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

print('Numpy version : ',np.__version__)
print('Pandas version : ',pd.__version__)
print('Seaborn version : ',sns.__version__)
# Out:
# Numpy version :  1.20.3
# Pandas version :  1.3.2
# Seaborn version :  0.11.2

# %%
wine_data = pd.read_csv('winequality-white.csv', 
                       names = ['Fixed Acidity', 'Volatile Acidity','Citric Acid','Residual Sugar',
                               'Chlorides','Free Sulfur Dioxide','Total Sulfur Dioxide','Density',
                               'pH','Sulphates','Alcohol','Quality'],
                       skiprows=1,
                       sep=r'\s*;\s*', engine='python')

# %%
wine_data.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    Free Sulfur Dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    Alcohol  Quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine_data.shape
# Out:
# (4898, 12)

# %%
#wine_data.describe().T
wine_data.describe()
# Out:
#        Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          Chlorides  Free Sulfur Dioxide  Total Sulfur Dioxide      Density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    Sulphates      Alcohol      Quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
wine_data.isna().sum()
# Out:
# Fixed Acidity           0
# Volatile Acidity        0
# Citric Acid             0
# Residual Sugar          0
# Chlorides               0
# Free Sulfur Dioxide     0
# Total Sulfur Dioxide    0
# Density                 0
# pH                      0
# Sulphates               0
# Alcohol                 0
# Quality                 0
# dtype: int64

# %%
sns.distplot(wine_data['Alcohol'])
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol', ylabel='Density'>

# %%
f, ax =plt.subplots(figsize=(15,8))

sns.distplot(wine_data['Alcohol'])
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol', ylabel='Density'>

# %%
f, ax =plt.subplots(figsize=(15,8))

sns.distplot(wine_data['Alcohol'], kde = False)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol'>

# %%
f, ax =plt.subplots(figsize=(15,8))

sns.distplot(wine_data['Alcohol'], kde = False, rug = True)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol'>

# %%
f, ax =plt.subplots(figsize=(15,8))

sns.rugplot(wine_data['Alcohol'], height = 0.5, axis = 'x')
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol'>

# %%
f, ax =plt.subplots(figsize=(15,8))
#Bins parameter shows the number of bins
sns.distplot(wine_data['Alcohol'], bins = 30, kde = False, rug = True)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol'>

# %%
f, ax =plt.subplots(figsize=(15,8))
#Bins parameter shows the number of bins
sns.distplot(wine_data['Alcohol'], bins = 75, kde = False, rug = True)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol'>

# %%
f, ax =plt.subplots(figsize=(15,8))
#Don't want to see the histogram 

sns.distplot(wine_data['Alcohol'], hist=False, rug = True)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol', ylabel='Density'>

# %%
f, ax =plt.subplots(figsize=(15,8))

sns.set(color_codes=True)
sns.kdeplot(wine_data['Alcohol'], shade=True, color='r')
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Density'>

# %%
f, ax =plt.subplots(figsize=(15,8))

sns.kdeplot(wine_data['Alcohol'])
sns.kdeplot(wine_data['Alcohol'], bw=0.04, label = 'bw: 0.04')
sns.kdeplot(wine_data['Alcohol'], bw=.2, label = 'bw: .2')
sns.kdeplot(wine_data['Alcohol'], bw=2, label = 'bw: 2')
sns.kdeplot(wine_data['Alcohol'], bw=5, label = 'bw: 5')
ax.legend(loc=0)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.04 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x = 'Free Sulfur Dioxide', y='Total Sulfur Dioxide', data = wine_data)

# %%
sns.jointplot(x = 'Free Sulfur Dioxide', y='Total Sulfur Dioxide', data = wine_data,
             xlim={0,100}, ylim={0,250})

# %%
with sns.axes_style('white'):
    sns.jointplot(x = 'Free Sulfur Dioxide', y='Total Sulfur Dioxide', data = wine_data,
                  kind = 'hex', color='k',
             xlim={0,100}, ylim={0,250})
    
#hexbin plot(histogram with bivariate data)

# %%
sns.jointplot(x = 'Free Sulfur Dioxide', y='Total Sulfur Dioxide', data = wine_data,
                  kind = 'kde', shade=True,
             xlim={0,100}, ylim={0,250})

# %%
sns.kdeplot(wine_data['Free Sulfur Dioxide'], wine_data['Total Sulfur Dioxide'], shade=True, clip=(0,250))
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Free Sulfur Dioxide', ylabel='Total Sulfur Dioxide'>

# %%
f, ax = plt.subplots(figsize=(10,8))

sns.kdeplot(wine_data['Free Sulfur Dioxide'], wine_data['Total Sulfur Dioxide'], shade=True, clip=(0,250))

sns.rugplot(wine_data['Free Sulfur Dioxide'], color = 'g', height=0.05)
sns.rugplot(wine_data['Total Sulfur Dioxide'], vertical=True, height=0.05)

plt.xlim(-20, 100)
plt.ylim(-50, 400)
# Out:
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/catalina/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2112: FutureWarning: Using `vertical=True` to control the orientation of the plot  is deprecated. Instead, assign the data directly to `y`.
#   warnings.warn(msg, FutureWarning)
# (-50.0, 400.0)
